# %%
import pandas as pd
import os
import csv
from datetime import datetime
import numpy as np

# %% [markdown]
# # Infection and Mobility Data Validity Checks

# %% [markdown]
# We check whether there are negative or null values in the infection dataset us-counties-4-26.csv
# and the mobility dataset DL-us-mobility-daterow-4-23.csv. The code below prints out rows with
# negative or null values for the cases, deaths, mobility, and mobility index values of the two
# files.

# %% [markdown]
# NYTimes Data

# %%
# Check whether cases and deaths in NYTimes data have negative values

f = open(r"us-counties-4-26.csv")
csv_f = csv.reader(f)
count = 0

for row in csv_f:
    if count == 0:
        count+=1
        continue
    if int(row[4]) < 0 or int(row[5]) < 0 or row[4] == "" or row[5] == "":
        print(row)
        
f.close()

# %% [markdown]
# Descartes Lab Mobility Data

# %%
# Check whether m50 and m50_index data have negative or null values 
f = open(r"DL-us-mobility-daterow-4-23.csv")
csv_f = csv.reader(f)
count = 0

for row in csv_f:
    if count == 0:
        count += 1
        continue
    if int(row[-1]) < 0 or float(row[-2]) < 0.0 or row[-1] == "" or row[-2] == "":
        print(row)
f.close()

# %% [markdown]
# # Time Series data wrangling and cleaning

# %% [markdown]
# NYTimes case and death records start on different dates for different counties.
# Thus, must register case and death data in dataframes where columns are dates.
# This is important for the time-series cross correlation analysis as scipy.correlate
# will not check that the value corresponds to the correct date.
# If there are missing values in the time-series data, when using scipy.correlate,
# the sequence will just be truncated and shifted, producing a different waveform
#
# The NYTimes infection and death dataset file is us-counties-4-26.csv, updated 4/26.
#
# The Descartes mobility index data DL-us-m50_index-4-23.csv, updated 4/23,  is already
# in the desired structure and data for all counties start and end on the same dates.
# However, it is actually missing data on 2020-04-20. A column of zeros is added for 2020-04-20
# instead of interpolating as there there will be smoothing prior to calculting the
# cross-correlation.
#
# DL-us-m50_index-4-23.csv provides the same data as DL-us-mobility-daterow-4-23.csv
# except the data has already been transposed
#
# Null values are replaced with zeros.

# %% [markdown]
# Time Series: Descartes Lab Mobility Index Data

# %%
#Descartes mobility index data is available between 2020-03-01 and 2020-04-23
dl = pd.read_csv('DL-us-m50_index-4-23.csv')

print('Number of rows with NULL fips: ' + str(dl.loc[dl['fips'].isnull()].shape[0]))

#NaN fips numbers converted to 0, otherwise converted to int
dl['fips'] = dl['fips'].apply(lambda x: 0 if np.isnan(x) else int(x))

#were no fips with zero values previously 
print('Number of rows with 0 fips after transformation: ' + str(dl.loc[dl['fips']==0].shape[0]))
# Out:
# Number of rows with NULL fips: 1
# Number of rows with 0 fips after transformation: 1

# %%
dl.head()
# Out:
#   country_code  admin_level   admin1          admin2  fips  2020-03-01  \
# 0           US            1  Alabama             NaN     1        79.0
# 1           US            2  Alabama  Autauga County  1001        49.0
# 2           US            2  Alabama  Baldwin County  1003        81.0
# 3           US            2  Alabama  Barbour County  1005        90.0
# 4           US            2  Alabama     Bibb County  1007        53.0
#
#    2020-03-02  2020-03-03  2020-03-04  2020-03-05  ...  2020-04-13  \
# 0        98.0       100.0        96.0       104.0  ...        50.0
# 1       100.0        95.0        95.0       100.0  ...        43.0
# 2       100.0        95.0        90.0       102.0  ...        48.0
# 3       107.0       100.0        70.0        88.0  ...        50.0
# 4        95.0       100.0        94.0       111.0  ...        43.0
#
#    2020-04-14  2020-04-15  2020-04-16  2020-04-17  2020-04-18  2020-04-19  \
# 0        51.0        56.0        59.0        68.0        49.0         4.0
# 1        36.0        42.0        45.0        56.0        34.0         0.0
# 2        49.0        52.0        53.0        57.0        43.0        16.0
# 3        51.0        54.0        62.0        67.0        58.0         7.0
# 4        51.0        50.0        55.0        55.0        45.0         4.0
#
#    2020-04-21  2020-04-22  2020-04-23
# 0        62.0        62.0        47.0
# 1        48.0        46.0        35.0
# 2        58.0        59.0        36.0
# 3        71.0        78.0        50.0
# 4        59.0        53.0        35.0
#
# [5 rows x 58 columns]

# %%
dl['fips'].describe()
# Out:
# count     2722.00000
# mean     29586.14144
# std      15682.17198
# min          0.00000
# 25%      18031.50000
# 50%      28154.00000
# 75%      45016.50000
# max      56041.00000
# Name: fips, dtype: float64

# %% [markdown]
# No negative fips values, drop zero-valued rows. Also drop non-date columns, not including fips

# %%
dl = dl.loc[dl['fips'] != 0]
dl.drop(['country_code', 'admin_level', 'admin1', 'admin2'], axis = 1, inplace = True)
dl.head()
# Out:
#    fips  2020-03-01  2020-03-02  2020-03-03  2020-03-04  2020-03-05  \
# 0     1        79.0        98.0       100.0        96.0       104.0
# 1  1001        49.0       100.0        95.0        95.0       100.0
# 2  1003        81.0       100.0        95.0        90.0       102.0
# 3  1005        90.0       107.0       100.0        70.0        88.0
# 4  1007        53.0        95.0       100.0        94.0       111.0
#
#    2020-03-06  2020-03-07  2020-03-08  2020-03-09  ...  2020-04-13  \
# 0       123.0       107.0        80.0       103.0  ...        50.0
# 1       116.0        79.0        58.0       108.0  ...        43.0
# 2       114.0        95.0        82.0        96.0  ...        48.0
# 3       118.0       141.0        79.0        98.0  ...        50.0
# 4       133.0       112.0        51.0       124.0  ...        43.0
#
#    2020-04-14  2020-04-15  2020-04-16  2020-04-17  2020-04-18  2020-04-19  \
# 0        51.0        56.0        59.0        68.0        49.0         4.0
# 1        36.0        42.0        45.0        56.0        34.0         0.0
# 2        49.0        52.0        53.0        57.0        43.0        16.0
# 3        51.0        54.0        62.0        67.0        58.0         7.0
# 4        51.0        50.0        55.0        55.0        45.0         4.0
#
#    2020-04-21  2020-04-22  2020-04-23
# 0        62.0        62.0        47.0
# 1        48.0        46.0        35.0
# 2        58.0        59.0        36.0
# 3        71.0        78.0        50.0
# 4        59.0        53.0        35.0
#
# [5 rows x 54 columns]

# %% [markdown]
# A column for 2020-04-20 is missing. Add a column of zeros. Also replace NaN's with 0

# %%
dl['2020-04-20'] = 0.0
dl.fillna(0, inplace = True)
dl.head()
# Out:
#    fips  2020-03-01  2020-03-02  2020-03-03  2020-03-04  2020-03-05  \
# 0     1        79.0        98.0       100.0        96.0       104.0
# 1  1001        49.0       100.0        95.0        95.0       100.0
# 2  1003        81.0       100.0        95.0        90.0       102.0
# 3  1005        90.0       107.0       100.0        70.0        88.0
# 4  1007        53.0        95.0       100.0        94.0       111.0
#
#    2020-03-06  2020-03-07  2020-03-08  2020-03-09  ...  2020-04-14  \
# 0       123.0       107.0        80.0       103.0  ...        51.0
# 1       116.0        79.0        58.0       108.0  ...        36.0
# 2       114.0        95.0        82.0        96.0  ...        49.0
# 3       118.0       141.0        79.0        98.0  ...        51.0
# 4       133.0       112.0        51.0       124.0  ...        51.0
#
#    2020-04-15  2020-04-16  2020-04-17  2020-04-18  2020-04-19  2020-04-21  \
# 0        56.0        59.0        68.0        49.0         4.0        62.0
# 1        42.0        45.0        56.0        34.0         0.0        48.0
# 2        52.0        53.0        57.0        43.0        16.0        58.0
# 3        54.0        62.0        67.0        58.0         7.0        71.0
# 4        50.0        55.0        55.0        45.0         4.0        59.0
#
#    2020-04-22  2020-04-23  2020-04-20
# 0        62.0        47.0         0.0
# 1        46.0        35.0         0.0
# 2        59.0        36.0         0.0
# 3        78.0        50.0         0.0
# 4        53.0        35.0         0.0
#
# [5 rows x 55 columns]

# %% [markdown]
# Time Series: NYTimes data

# %%
nyt = pd.read_csv('us-counties-4-26.csv')

print('Number of rows with NULL fips: ' + str(nyt.loc[nyt['fips'].isnull()].shape[0]))

#NaN fips numbers converted to 0, otherwise converted to int
nyt['fips'] = nyt['fips'].apply(lambda x: 0 if np.isnan(x) else int(x))

#were no fips with zero values previously 
print('Number of rows with 0 fips after transformation: ' + str(nyt.loc[nyt['fips']==0].shape[0]))
# Out:
# Number of rows with NULL fips: 1097
# Number of rows with 0 fips after transformation: 1097

# %%
#show transformed dataframe
nyt.head()
# Out:
#          date     county       state   fips  cases  deaths
# 0  2020-01-21  Snohomish  Washington  53061      1       0
# 1  2020-01-22  Snohomish  Washington  53061      1       0
# 2  2020-01-23  Snohomish  Washington  53061      1       0
# 3  2020-01-24       Cook    Illinois  17031      1       0
# 4  2020-01-24  Snohomish  Washington  53061      1       0

# %%
nyt['fips'].describe()
# Out:
# count    89772.000000
# mean     29409.773894
# std      15716.079457
# min          0.000000
# 25%      17161.000000
# 50%      28131.000000
# 75%      44001.000000
# max      56043.000000
# Name: fips, dtype: float64

# %%
#no negative fips numbers
#drop rows with fips == 0
nyt = nyt.loc[nyt['fips'] != 0]

# %%
temp = nyt['date'].unique().tolist()
nytdates = [datetime.strptime(x, '%Y-%m-%d') for x in temp]

firstdate = datetime.strftime(min(nytdates), '%Y-%m-%d')
lastdate = datetime.strftime(max(nytdates), '%Y-%m-%d')

# %% [markdown]
# Create list of all dates between first and last dates for columns of new dataframe

# %%
def get_all_dates(fd, ld):
    #returns list of all dates from firstdate fd to lastdate ld
    #fd and ld are strings in YYYY-MM-DD format
    
    monthlastday = {1: 31, 2: 29, 3: 31, 4: 30, 5: 31}
    
    fdmint = int(fd[5:7].lstrip('0'))
    ldmint = int(ld[5:7].lstrip('0'))
    
    monthlistint = list(range(fdmint, ldmint+1))
    
    datetimes = []
    
    for m in monthlistint:
        
        if m == fdmint:
            firstday = int(fd[8:10].lstrip('0'))
        else:
            firstday = 1
            
        if m == ldmint:
            lastday = int(ld[8:10].lstrip('0'))
        else:
            lastday = monthlastday[m]
        for d in range(firstday, lastday+1):

            datetimes.append('2020-' + datetime.strftime(datetime.strptime(str(m), '%m'), '%m') 
                           +'-' + datetime.strftime(datetime.strptime(str(d), '%d'), '%d') )
    
    return datetimes

columns = get_all_dates(firstdate, lastdate)
columns.insert(0, 'fips')

# %% [markdown]
# Create new dataframe with dates as columns. Use pandas dataframe append to take
# care of matching values of rows by column name. Will take a few minutes.

# %%
#for each fip, append cases and deaths to transposed dataframes

fips = nyt['fips'].unique().tolist()
nfips = len(fips)

nyttransposedcases = pd.DataFrame(columns = columns)
nyttransposeddeaths = pd.DataFrame(columns = columns)

row = 1
for fip in fips:
    
    print('Working on fip ' + str(row) + '/' + str(nfips), end = "\r")
    
    tempcases = nyt.loc[nyt['fips'] == fip, ['date', 'cases']].set_index('date').T
    tempcases['fips'] = fip
    
    tempdeaths = nyt.loc[nyt['fips'] == fip, ['date', 'deaths']].set_index('date').T
    tempdeaths['fips'] = fip
    
    nyttransposedcases = nyttransposedcases.append(tempcases).reset_index(drop = True)
    nyttransposedcases.iloc[-1].fillna(0, axis = 0, inplace = True)
    
    nyttransposeddeaths = nyttransposeddeaths.append(tempdeaths).reset_index(drop = True)
    nyttransposeddeaths.iloc[-1].fillna(0, axis = 0, inplace = True)
    
    row = row + 1
# Out:
# Working on fip 13/2807
# C:\Users\Franklin.000\Anaconda3\lib\site-packages\pandas\core\frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
# Working on fip 2807/2807

# %% [markdown]
# New dataframes nyttransposedcases and nyttransposeddeaths

# %%
nyttransposedcases.head()
# Out:
#     fips 2020-01-21 2020-01-22 2020-01-23 2020-01-24 2020-01-25 2020-01-26  \
# 0  53061          1          1          1          1          1          1
# 1  17031          0          0          0          1          1          1
# 2   6059          0          0          0          0          1          1
# 3   4013          0          0          0          0          0          1
# 4   6037          0          0          0          0          0          1
#
#   2020-01-27 2020-01-28 2020-01-29  ... 2020-04-16 2020-04-17 2020-04-18  \
# 0          1          1          1  ...       2031       2055       2092
# 1          1          1          1  ...      18087      19391      20395
# 2          1          1          1  ...       1425       1501       1556
# 3          1          1          1  ...       2264       2404       2491
# 4          1          1          1  ...      10854      11391      12021
#
#   2020-04-19 2020-04-20 2020-04-21 2020-04-22 2020-04-23 2020-04-24 2020-04-25
# 0       2142       2162       2162       2208       2239       2267       2297
# 1      21272      22101      23181      24546      25811      27616      29058
# 2       1636       1676       1691       1753       1827       1845       1969
# 3       2589       2636       2738       2846       2970       3116       3234
# 4      12341      13816      15140      16435      17508      18545      19107
#
# [5 rows x 97 columns]

# %%
nyttransposeddeaths.head()
# Out:
#     fips 2020-01-21 2020-01-22 2020-01-23 2020-01-24 2020-01-25 2020-01-26  \
# 0  53061          0          0          0          0          0          0
# 1  17031          0          0          0          0          0          0
# 2   6059          0          0          0          0          0          0
# 3   4013          0          0          0          0          0          0
# 4   6037          0          0          0          0          0          0
#
#   2020-01-27 2020-01-28 2020-01-29  ... 2020-04-16 2020-04-17 2020-04-18  \
# 0          0          0          0  ...         85         87         92
# 1          0          0          0  ...        722        760        860
# 2          0          0          0  ...         25         28         32
# 3          0          0          0  ...         64         69         70
# 4          0          0          0  ...        455        495        576
#
#   2020-04-19 2020-04-20 2020-04-21 2020-04-22 2020-04-23 2020-04-24 2020-04-25
# 0         92         96         98         98         99        102        103
# 1        877        915       1002       1072       1142       1220       1267
# 2         32         33         33         34         36         36         38
# 3         75         75         84         97        115        120        121
# 4        600        617        663        729        797        850        895
#
# [5 rows x 97 columns]

# %% [markdown]
# ## Cleaning non-matching keys in multiple datasets

# %% [markdown]
# For the prediction part the third dataset will be used:

# %%
econ = pd.read_csv('Unemployment.csv')
econ
# Out:
#        FIPS State                Area_name  Rural_urban_continuum_code_2013  \
# 0         0    US            United States                              NaN
# 1      1000    AL                  Alabama                              NaN
# 2      1001    AL       Autauga County, AL                              2.0
# 3      1003    AL       Baldwin County, AL                              3.0
# 4      1005    AL       Barbour County, AL                              6.0
# ...     ...   ...                      ...                              ...
# 3270  72145    PR  Vega Baja Municipio, PR                              1.0
# 3271  72147    PR    Vieques Municipio, PR                              7.0
# 3272  72149    PR   Villalba Municipio, PR                              2.0
# 3273  72151    PR    Yabucoa Municipio, PR                              1.0
# 3274  72153    PR      Yauco Municipio, PR                              2.0
#
#       Urban_influence_code_2013  Metro_2013  Civilian_labor_force_2007   \
# 0                           NaN         NaN                 152,191,093
# 1                           NaN         NaN                  2,175,612
# 2                           2.0         1.0                     24,383
# 3                           2.0         1.0                     82,659
# 4                           6.0         0.0                     10,334
# ...                         ...         ...                         ...
# 3270                        1.0         1.0                     21,115
# 3271                       12.0         0.0                      3,317
# 3272                        2.0         1.0                      9,479
# 3273                        1.0         1.0                     11,425
# 3274                        2.0         1.0                     16,635
#
#       Employed_2007   Unemployed_2007   Unemployment_rate_2007  ...  \
# 0        145,156,134         7,034,959                     4.6  ...
# 1         2,089,127            86,485                      4.0  ...
# 2            23,577               806                      3.3  ...
# 3            80,099             2,560                      3.1  ...
# 4             9,684               650                      6.3  ...
# ...              ...               ...                     ...  ...
# 3270         18,445             2,670                     12.6  ...
# 3271          2,955               362                     10.9  ...
# 3272          8,223             1,256                     13.3  ...
# 3273          9,348             2,077                     18.2  ...
# 3274         14,451             2,184                     13.1  ...
#
#      Civilian_labor_force_2017 Employed_2017 Unemployed_2017  \
# 0                  160,273,906   153,293,830       6,980,076
# 1                      2178243       2081676           96567
# 2                        25972         24958            1014
# 3                        92090         88342            3748
# 4                         8317          7831             486
# ...                        ...           ...             ...
# 3270                     13409         11743            1666
# 3271                      3026          2588             438
# 3272                      7554          6088            1466
# 3273                      8996          7510            1486
# 3274                     10156          8407            1749
#
#       Unemployment_rate_2017 Civilian_labor_force_2018 Employed_2018  \
# 0                        4.4               161,640,488   155,344,043
# 1                        4.4                 2,198,837     2,112,347
# 2                        3.9                    25,957        25,015
# 3                        4.1                    93,849        90,456
# 4                        5.8                     8,373         7,940
# ...                      ...                       ...           ...
# 3270                    12.4                    13,199        11,826
# 3271                    14.5                     2,734         2,283
# 3272                    19.4                     7,329         6,164
# 3273                    16.5                     8,826         7,566
# 3274                    17.2                     9,770         8,329
#
#      Unemployed_2018  Unemployment_rate_2018 Median_Household_Income_2018  \
# 0          6,296,445                     3.9                     $61,937
# 1             86,490                     3.9                     $49,881
# 2                942                     3.6                     $59,338
# 3              3,393                     3.6                     $57,588
# 4                433                     5.2                     $34,382
# ...              ...                     ...                          ...
# 3270           1,373                    10.4                          NaN
# 3271             451                    16.5                          NaN
# 3272           1,165                    15.9                          NaN
# 3273           1,260                    14.3                          NaN
# 3274           1,441                    14.7                          NaN
#
#      Med_HH_Income_Percent_of_State_Total_2018
# 0                                          NaN
# 1                                        100.0
# 2                                        119.0
# 3                                        115.5
# 4                                         68.9
# ...                                        ...
# 3270                                       NaN
# 3271                                       NaN
# 3272                                       NaN
# 3273                                       NaN
# 3274                                       NaN
#
# [3275 rows x 56 columns]

# %%
mobility = pd.read_csv('DL-us-m50_index-4-23.csv')
cases = pd.read_csv('us-counties-4-26.csv')

# %% [markdown]
# Since mobility dataset was the shortest one, the decision was made to use it as root

# %%
mobility_fips = mobility[mobility['admin_level']==2]['fips']
not_overlap_fips = [int(fips) for fips in mobility_fips if fips not in list(econ['FIPS']) ]
not_overlap_names = [mobility[mobility['fips']==fips]['admin2'].iloc[0] for fips in not_overlap_fips]
print(len(not_overlap_fips), not_overlap_names , " county did not match")
mobility = mobility[~mobility['fips'].isin(not_overlap_fips)]
# Out:
# 1 ['City of Bedford']  county did not match

# %%
mobility_fips = mobility[mobility['admin_level']==2]['fips']
not_overlap_fips = [int(fips) for fips in mobility_fips if fips not in list(cases['fips']) ]
not_overlap_names = [mobility[mobility['fips']==fips]['admin2'].iloc[0] for fips in not_overlap_fips]
print(len(not_overlap_fips), not_overlap_names , " county did not match")
mobility = mobility[~mobility['fips'].isin(not_overlap_fips)]
# Out:
# 115 ['North Slope Borough', 'Little River County', 'Montgomery County', 'Lassen County', 'Mariposa County', 'Benewah County', 'Franklin County', 'Shoshone County', 'Brown County', 'Edgar County', 'Edwards County', 'Putnam County', 'Calhoun County', 'Davis County', 'Decatur County', 'Emmet County', 'Floyd County', 'Fremont County', 'Ida County', 'Lucas County', 'Monroe County', 'Palo Alto County', 'Pocahontas County', 'Sac County', 'Allen County', 'Brown County', 'Ellsworth County', 'Harper County', 'Kingman County', 'Marshall County', 'Nemaha County', 'Pawnee County', 'Russell County', 'Thomas County', 'Bell County', 'Estill County', 'Harlan County', 'Magoffin County', 'Metcalfe County', 'Owen County', 'Iron County', 'Grant County', 'Hubbard County', 'Kanabec County', 'Lake County', 'Lake of the Woods County', 'Pope County', 'Stevens County', 'Wadena County', 'Barton County', 'Dent County', 'Douglas County', 'Grundy County', 'Laclede County', 'Lawrence County', 'Shannon County', 'Wayne County', 'Custer County', 'Dawson County', 'Fergus County', 'Holt County', 'Jefferson County', 'Keith County', 'Richardson County', 'Storey County', 'Sierra County', 'Bronx', 'Kings County', 'New York County', 'Queens County', 'Richmond County', 'Avery County', 'Camden County', 'Swain County', 'Yancey County', 'Traill County', 'Vinton County', 'Blaine County', 'Coal County', 'Ellis County', 'Hughes County', 'Pushmataha County', 'Baker County', 'Custer County', 'Grant County', 'Archer County', 'Bailey County', 'Brewster County', 'Coleman County', 'Crockett County', 'Culberson County', 'Fisher County', 'Hardeman County', 'Kimble County', 'Loving County', 'Mills County', 'Reagan County', 'Reeves County', 'Refugio County', 'Runnels County', 'San Saba County', 'Somervell County', 'Sutton County', 'Upton County', 'Ward County', 'Beaver County', 'City of Martinsville', 'Dickenson County', 'Pocahontas County', 'Ritchie County', 'Burnett County', 'Langlade County', 'Lincoln County', 'Taylor County', 'Platte County']  county did not match
